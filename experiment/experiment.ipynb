# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
# 필수 패키지 설치
# !pip install olefile

# %%
import olefile
import zlib

def list_streams(hwp_path):
    """OLE 파일의 스트림과 스토리지를 나열"""
    ole = olefile.OleFileIO(hwp_path)
    print("=== Streams and Storages ===")
    for entry in ole.listdir():
        print("/".join(entry))
    ole.close()

def read_section0(hwp_path):
    """BodyText/Section0 스트림 읽고 zlib 해제"""
    ole = olefile.OleFileIO(hwp_path)
    
    # BodyText/Section0 stream 경로
    stream_path = ["BodyText", "Section0"]

    if ole.exists(stream_path):
        data = ole.openstream(stream_path).read()
        # BodyText는 zlib 압축된 상태
        # HWP 문서 스펙: 첫 4바이트는 레코드 헤더로 간주 가능 (간단화)
        header = data[:4]
        compressed = data[4:]
        try:
            decompressed = zlib.decompress(compressed)
            print("=== Decompressed BodyText (first 200 bytes) ===")
            print(decompressed[:200])
        except Exception as e:
            print("[!] zlib 해제 실패:", e)
    else:
        print("[!] BodyText/Section0 스트림이 없습니다.")

    ole.close()

# if __name__ == "__main__":
#     hwp_file = "sample.hwp"

#     # 1) 스트림 리스트 확인
#     list_streams(hwp_file)

#     # 2) Section0 읽기 및 zlib 해제
#     read_section0(hwp_file)

hwp_file = "sample_file.hwp"

# 1) 스트림 리스트 확인
list_streams(hwp_file)

# 2) Section0 읽기 및 zlib 해제
read_section0(hwp_file)
# Out:
# === Streams and Storages ===
# HwpSummaryInformation
# BinData/BIN0001.tif
# BodyText/Section0
# DocInfo
# DocOptions/_LinkDoc
# FileHeader
# PrvImage
# PrvText
# Scripts/DefaultJScript
# Scripts/JScriptVersion
# [!] zlib 해제 실패: Error -3 while decompressing data: incorrect header check

# %%
import olefile
import struct
import zlib

def list_streams(hwp_path):
    ole = olefile.OleFileIO(hwp_path)
    print("=== Streams and Storages ===")
    for entry in ole.listdir():
        print("/".join(entry))
    ole.close()

def check_compression(hwp_path):
    ole = olefile.OleFileIO(hwp_path)
    if ole.exists("FileHeader"):
        header_data = ole.openstream("FileHeader").read()
        compression_flag = header_data[36]
        print(f"압축 플래그 값: {compression_flag}")
        return compression_flag & 1 == 1
    ole.close()
    return False

def read_section0(hwp_path, is_compressed):
    ole = olefile.OleFileIO(hwp_path)
    stream_path = ["BodyText", "Section0"]

    if ole.exists(stream_path):
        data = ole.openstream(stream_path).read()
        compressed_size, uncompressed_size = struct.unpack("<HH", data[:4])
        compressed_data = data[4:]

        print(f"압축 크기: {compressed_size}, 해제 후 크기: {uncompressed_size}")

        if is_compressed:
            try:
                # 핵심 포인트: -15로 raw DEFLATE 해제
                decompressed = zlib.decompress(compressed_data, -15)
                print("=== Decompressed BodyText (first 200 bytes) ===")
                print(decompressed[:200])
            except Exception as e:
                print("[!] zlib 해제 실패:", e)
        else:
            print("=== Uncompressed BodyText (first 200 bytes) ===")
            print(data[4:204])

    else:
        print("[!] BodyText/Section0 스트림이 없습니다.")

    ole.close()

hwp_file = "sample_file.hwp"

print("Hello, World!")
list_streams(hwp_file)

is_compressed = check_compression(hwp_file)

read_section0(hwp_file, is_compressed)
# Out:
# Hello, World!
# === Streams and Storages ===
# HwpSummaryInformation
# BinData/BIN0001.tif
# BodyText/Section0
# DocInfo
# DocOptions/_LinkDoc
# FileHeader
# PrvImage
# PrvText
# Scripts/DefaultJScript
# Scripts/JScriptVersion
# 압축 플래그 값: 1
# 압축 크기: 22212, 해제 후 크기: 20445
# [!] zlib 해제 실패: Error -3 while decompressing data: invalid code lengths set

# %%
# !pip install pyhwpx
# Out:
# Collecting pyhwpx
#   Downloading pyhwpx-1.3.4-py3-none-any.whl.metadata (3.2 kB)
# Collecting numpy (from pyhwpx)
#   Downloading numpy-2.3.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting pandas (from pyhwpx)
#   Downloading pandas-2.3.1-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: pywin32 in d:\kt\document_parser_hwp\experiment\.venv\lib\site-packages (from pyhwpx) (310)
# Collecting openpyxl (from pyhwpx)
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pyperclip (from pyhwpx)
#   Downloading pyperclip-1.9.0.tar.gz (20 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting Pillow (from pyhwpx)
#   Downloading pillow-11.3.0-cp312-cp312-win_amd64.whl.metadata (9.2 kB)
# Collecting et-xmlfile (from openpyxl->pyhwpx)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\kt\document_parser_hwp\experiment\.venv\lib\site-packages (from pandas->pyhwpx) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->pyhwpx)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->pyhwpx)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in d:\kt\document_parser_hwp\experiment\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->pyhwpx) (1.17.0)
# Downloading pyhwpx-1.3.4-py3-none-any.whl (369 kB)
# Downloading numpy-2.3.1-cp312-cp312-win_amd64.whl (12.7 MB)
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.7 MB 3.4 MB/s eta 0:00:04
#    --- ------------------------------------ 1.0/12.7 MB 2.6 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.6/12.7 MB 2.4 MB/s eta 0:00:05
#    ------ --------------------------------- 2.1/12.7 MB 2.6 MB/s eta 0:00:05
#    -------- ------------------------------- 2.6/12.7 MB 2.4 MB/s eta 0:00:05
#    --------- ------------------------------ 3.1/12.7 MB 2.5 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.4/12.7 MB 2.4 MB/s eta 0:00:04
#    ------------- -------------------------- 4.2/12.7 MB 2.5 MB/s eta 0:00:04
#    ------------- -------------------------- 4.5/12.7 MB 2.4 MB/s eta 0:00:04
#    -------------- ------------------------- 4.7/12.7 MB 2.2 MB/s eta 0:00:04
#    --------------- ------------------------ 5.0/12.7 MB 2.3 MB/s eta 0:00:04
#    ------------------ --------------------- 5.8/12.7 MB 2.3 MB/s eta 0:00:04
#    ------------------- -------------------- 6.3/12.7 MB 2.3 MB/s eta 0:00:03
#    --------------------- ------------------ 6.8/12.7 MB 2.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 7.1/12.7 MB 2.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 7.6/12.7 MB 2.3 MB/s eta 0:00:03
#    ------------------------- -------------- 8.1/12.7 MB 2.3 MB/s eta 0:00:02
#    --------------------------- ------------ 8.9/12.7 MB 2.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.4/12.7 MB 2.4 MB/s eta 0:00:02
#    ------------------------------ --------- 9.7/12.7 MB 2.4 MB/s eta 0:00:02
#    -------------------------------- ------- 10.2/12.7 MB 2.3 MB/s eta 0:00:02
#    -------------------------------- ------- 10.5/12.7 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.0/12.7 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.0/12.7 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------ --- 11.5/12.7 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 12.1/12.7 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 12.1/12.7 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 12.3/12.7 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.7/12.7 MB 2.1 MB/s eta 0:00:00
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Downloading pandas-2.3.1-cp312-cp312-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 1.4 MB/s eta 0:00:08
#    --- ------------------------------------ 1.0/11.0 MB 1.6 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.6/11.0 MB 1.8 MB/s eta 0:00:06
#    ------ --------------------------------- 1.8/11.0 MB 1.9 MB/s eta 0:00:05
#    ------- -------------------------------- 2.1/11.0 MB 1.8 MB/s eta 0:00:06
#    -------- ------------------------------- 2.4/11.0 MB 1.7 MB/s eta 0:00:06
#    ----------- ---------------------------- 3.1/11.0 MB 1.9 MB/s eta 0:00:05
#    ------------- -------------------------- 3.7/11.0 MB 1.9 MB/s eta 0:00:04
#    -------------- ------------------------- 3.9/11.0 MB 2.0 MB/s eta 0:00:04
#    ---------------- ----------------------- 4.5/11.0 MB 1.9 MB/s eta 0:00:04
#    ----------------- ---------------------- 4.7/11.0 MB 1.9 MB/s eta 0:00:04
#    ------------------- -------------------- 5.2/11.0 MB 2.0 MB/s eta 0:00:03
#    -------------------- ------------------- 5.5/11.0 MB 2.0 MB/s eta 0:00:03
#    -------------------- ------------------- 5.8/11.0 MB 1.9 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.3/11.0 MB 1.9 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.3/11.0 MB 1.9 MB/s eta 0:00:03
#    ------------------------ --------------- 6.8/11.0 MB 1.8 MB/s eta 0:00:03
#    ------------------------- -------------- 7.1/11.0 MB 1.8 MB/s eta 0:00:03
#    ------------------------- -------------- 7.1/11.0 MB 1.8 MB/s eta 0:00:03
#    ---------------------------- ----------- 7.9/11.0 MB 1.8 MB/s eta 0:00:02
#    ------------------------------ --------- 8.4/11.0 MB 1.9 MB/s eta 0:00:02
#    -------------------------------- ------- 8.9/11.0 MB 1.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 9.7/11.0 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/11.0 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 10.5/11.0 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 1.9 MB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading pillow-11.3.0-cp312-cp312-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/7.0 MB 3.0 MB/s eta 0:00:03
#    ------ --------------------------------- 1.0/7.0 MB 1.8 MB/s eta 0:00:04
#    --------- ------------------------------ 1.6/7.0 MB 2.0 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.8/7.0 MB 2.0 MB/s eta 0:00:03
#    ------------- -------------------------- 2.4/7.0 MB 1.9 MB/s eta 0:00:03
#    --------------- ------------------------ 2.6/7.0 MB 1.9 MB/s eta 0:00:03
#    --------------- ------------------------ 2.6/7.0 MB 1.9 MB/s eta 0:00:03
#    ---------------- ----------------------- 2.9/7.0 MB 1.7 MB/s eta 0:00:03
#    ------------------ --------------------- 3.1/7.0 MB 1.7 MB/s eta 0:00:03
#    --------------------- ------------------ 3.7/7.0 MB 1.6 MB/s eta 0:00:03
#    ---------------------- ----------------- 3.9/7.0 MB 1.6 MB/s eta 0:00:02
#    ------------------------ --------------- 4.2/7.0 MB 1.6 MB/s eta 0:00:02
#    ------------------------- -------------- 4.5/7.0 MB 1.5 MB/s eta 0:00:02
#    --------------------------- ------------ 4.7/7.0 MB 1.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.0/7.0 MB 1.6 MB/s eta 0:00:02
#    ------------------------------ --------- 5.2/7.0 MB 1.5 MB/s eta 0:00:02
#    ------------------------------ --------- 5.2/7.0 MB 1.5 MB/s eta 0:00:02
#    ------------------------------- -------- 5.5/7.0 MB 1.4 MB/s eta 0:00:02
#    ------------------------------- -------- 5.5/7.0 MB 1.4 MB/s eta 0:00:02
#    --------------------------------- ------ 5.8/7.0 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.0/7.0 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 6.3/7.0 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 6.3/7.0 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 6.6/7.0 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  6.8/7.0 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 1.2 MB/s eta 0:00:00
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (pyproject.toml): started
#   Building wheel for pyperclip (pyproject.toml): finished with status 'done'
#   Created wheel for pyperclip: filename=pyperclip-1.9.0-py3-none-any.whl size=11117 sha256=263ed3fdb446ace4ee1014e9eeecbd0ff974e39f40a6332046484dead1157854
#   Stored in directory: c:\users\kt\appdata\local\pip\cache\wheels\e0\e8\fc\8ab8aa326e33bc066ccd5f3ca9646eab4299881af933f94f09
# Successfully built pyperclip
# Installing collected packages: pytz, pyperclip, tzdata, Pillow, numpy, et-xmlfile, pandas, openpyxl, pyhwpx
#
#    ---------------------------------------- 0/9 [pytz]
#    ---------------------------------------- 0/9 [pytz]
#    ---- ----------------------------------- 1/9 [pyperclip]
#    -------- ------------------------------- 2/9 [tzdata]
#    -------- ------------------------------- 2/9 [tzdata]
#    ------------- -------------------------- 3/9 [Pillow]
#    ------------- -------------------------- 3/9 [Pillow]
#    ------------- -------------------------- 3/9 [Pillow]
#    ------------- -------------------------- 3/9 [Pillow]
#    ------------- -------------------------- 3/9 [Pillow]
#    ------------- -------------------------- 3/9 [Pillow]
#    ------------- -------------------------- 3/9 [Pillow]
#    ------------- -------------------------- 3/9 [Pillow]
#    ------------- -------------------------- 3/9 [Pillow]
#    ------------- -------------------------- 3/9 [Pillow]
#    ------------- -------------------------- 3/9 [Pillow]
#    ------------- -------------------------- 3/9 [Pillow]
#    ------------- -------------------------- 3/9 [Pillow]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    ----------------- ---------------------- 4/9 [numpy]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    -------------------------- ------------- 6/9 [pandas]
#    ------------------------------- -------- 7/9 [openpyxl]
#    ------------------------------- -------- 7/9 [openpyxl]
#    ------------------------------- -------- 7/9 [openpyxl]
#    ------------------------------- -------- 7/9 [openpyxl]
#    ------------------------------- -------- 7/9 [openpyxl]
#    ------------------------------- -------- 7/9 [openpyxl]
#    ------------------------------- -------- 7/9 [openpyxl]
#    ------------------------------- -------- 7/9 [openpyxl]
#    ------------------------------- -------- 7/9 [openpyxl]
#    ------------------------------- -------- 7/9 [openpyxl]
#    ------------------------------- -------- 7/9 [openpyxl]
#    ------------------------------- -------- 7/9 [openpyxl]
#    ------------------------------- -------- 7/9 [openpyxl]
#    ------------------------------- -------- 7/9 [openpyxl]
#    ------------------------------- -------- 7/9 [openpyxl]
#    ------------------------------- -------- 7/9 [openpyxl]
#    ------------------------------- -------- 7/9 [openpyxl]
#    ----------------------------------- ---- 8/9 [pyhwpx]
#    ---------------------------------------- 9/9 [pyhwpx]
#
# Successfully installed Pillow-11.3.0 et-xmlfile-2.0.0 numpy-2.3.1 openpyxl-3.1.5 pandas-2.3.1 pyhwpx-1.3.4 pyperclip-1.9.0 pytz-2025.2 tzdata-2025.2

# %%
from pyhwpx import Hwp

hwp = Hwp(visible=False)  # 백그라운드에서 작업!(마지막엔 꼭 hwp.quit()을 실행해야 함)
hwp.open("D:\KT\document_parser_hwp\experiment\sample_file.hwp")  # 원본문서를 열어서

# for i in range(hwp.PageCount):
#     hwp.MoveDocBegin()  # 문서 처음에서부터
#     hwp.MoveSelPageDown()  # 한 페이지 전체를 선택하고
#     hwp.MoveSelLeft()  # 한 칸 왼쪽으로 가줘야 2페이지(빈 페이지)가 안 생김
#     hwp.save_block_as(f"{i+1}.hwp")  # 블록 저장
#     hwp.DeletePage()  # 저장한 페이지는 삭제
hwp.save_as(f"{i+1}.hwp")  # 마지막(100번째) 페이지는 PageDown으로 블록이 안 잡히므로 별도 저장
hwp.msgbox('작업이 완료되었습니다.')  # 팝업 띄워주기
hwp.quit()  # 작업 완료되면 종료(창이 보이지 않으므로 꼭 코드로 종료하는 걸 잊지 말아야 함
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\K'
# <>:4: SyntaxWarning: invalid escape sequence '\K'
# C:\Users\KT\AppData\Local\Temp\ipykernel_5356\458350842.py:4: SyntaxWarning: invalid escape sequence '\K'
#   hwp.open("D:\KT\document_parser_hwp\experiment\sample_file.hwp")  # 원본문서를 열어서
# C:\Users\KT\AppData\Local\Temp\ipykernel_5356\458350842.py:4: SyntaxWarning: invalid escape sequence '\K'
#   hwp.open("D:\KT\document_parser_hwp\experiment\sample_file.hwp")  # 원본문서를 열어서
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from pyhwpx import Hwp
#       3 hwp = Hwp(visible=False)  # 백그라운드에서 작업!(마지막엔 꼭 hwp.quit()을 실행해야 함)
#       4 hwp.open("D:\KT\document_parser_hwp\experiment\sample_file.hwp")  # 원본문서를 열어서
#
# ModuleNotFoundError: No module named 'pyhwpx'

# %%
# !pip install pyhwpx

from pyhwpx import Hwp

hwp = Hwp()  # 보안모듈 자동 등록

# 텍스트 삽입
hwp.insert_text("Hello world!")

# win32com 방식으로도 실행 가능
pset = hwp.HParameterSet.HInsertText
pset.Text = "Hello world!"
hwp.HAction.Execute("InsertText", pset.HSet)

# 문서 저장
hwp.save_as("./helloworld.hwp")

# 한/글 종료
hwp.quit()
# Out:
# Requirement already satisfied: pyhwpx in d:\kt\document_parser_hwp\experiment\.venv\lib\site-packages (1.3.4)
# Requirement already satisfied: numpy in d:\kt\document_parser_hwp\experiment\.venv\lib\site-packages (from pyhwpx) (2.3.1)
# Requirement already satisfied: pandas in d:\kt\document_parser_hwp\experiment\.venv\lib\site-packages (from pyhwpx) (2.3.1)
# Requirement already satisfied: pywin32 in d:\kt\document_parser_hwp\experiment\.venv\lib\site-packages (from pyhwpx) (310)
# Requirement already satisfied: openpyxl in d:\kt\document_parser_hwp\experiment\.venv\lib\site-packages (from pyhwpx) (3.1.5)
# Requirement already satisfied: pyperclip in d:\kt\document_parser_hwp\experiment\.venv\lib\site-packages (from pyhwpx) (1.9.0)
# Requirement already satisfied: Pillow in d:\kt\document_parser_hwp\experiment\.venv\lib\site-packages (from pyhwpx) (11.3.0)
# Requirement already satisfied: et-xmlfile in d:\kt\document_parser_hwp\experiment\.venv\lib\site-packages (from openpyxl->pyhwpx) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\kt\document_parser_hwp\experiment\.venv\lib\site-packages (from pandas->pyhwpx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\kt\document_parser_hwp\experiment\.venv\lib\site-packages (from pandas->pyhwpx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\kt\document_parser_hwp\experiment\.venv\lib\site-packages (from pandas->pyhwpx) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\kt\document_parser_hwp\experiment\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->pyhwpx) (1.17.0)
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 get_ipython().system('pip install pyhwpx')
# ----> 3 from pyhwpx import Hwp
#       5 hwp = Hwp()  # 보안모듈 자동 등록
#       7 # 텍스트 삽입
#
# File d:\KT\document_parser_hwp\experiment\.venv\Lib\site-packages\pyhwpx\__init__.py:14
#       1 # import sys
#       2 #
#       3 # if not getattr(sys, 'frozen', False):  # pyinstaller 실행 환경이 아니면
#    (...)     11 #
#      12 #     sys.modules[__name__].Hwp = _get_Hwp()
# ---> 14 from .core import *
#      15 from .version import __version__
#      18 def tuple_to_addr():
#
# File d:\KT\document_parser_hwp\experiment\.venv\Lib\site-packages\pyhwpx\core.py:66
#      63     pass
#      65 # Type Library 파일 재생성
# ---> 66 win32.gencache.EnsureModule("{7D2B6F3C-1D95-4E0C-BF5A-5EE564186FBC}", 0, 1, 0)
#      69 __all__ = ["Hwp", "com_initialized"]
#      72 def com_initialized(func):
#
# File d:\KT\document_parser_hwp\experiment\.venv\Lib\site-packages\win32com\client\gencache.py:627, in EnsureModule(typelibCLSID, lcid, major, minor, progressInstance, bValidateFile, bForDemand, bBuildHidden)
#     625     return ret
#     626 # print("Rebuilding: ", major, minor)
# --> 627 module = MakeModuleForTypelib(
#     628     typelibCLSID,
#     629     lcid,
#     630     major,
#     631     minor,
#     632     progressInstance,
#     633     bForDemand=bForDemand,
#     634     bBuildHidden=bBuildHidden,
#     635 )
#     636 # If we replaced something, reload it
#     637 if bReloadNeeded:
#
# File d:\KT\document_parser_hwp\experiment\.venv\Lib\site-packages\win32com\client\gencache.py:343, in MakeModuleForTypelib(typelibCLSID, lcid, major, minor, progressInstance, bForDemand, bBuildHidden)
#     326 """Generate support for a type library.
#     327
#     328 Given the IID, LCID and version information for a type library, generate
#    (...)    339                     use the GUI progress bar.
#     340 """
#     341 from . import makepy
# --> 343 makepy.GenerateFromTypeLibSpec(
#     344     (typelibCLSID, lcid, major, minor),
#     345     progressInstance=progressInstance,
#     346     bForDemand=bForDemand,
#     347     bBuildHidden=bBuildHidden,
#     348 )
#     349 return GetModuleForTypelib(typelibCLSID, lcid, major, minor)
#
# File d:\KT\document_parser_hwp\experiment\.venv\Lib\site-packages\win32com\client\makepy.py:257, in GenerateFromTypeLibSpec(typelibInfo, file, verboseLevel, progressInstance, bForDemand, bBuildHidden)
#     254 if isinstance(typelibInfo, tuple):
#     255     # Tuple
#     256     typelibCLSID, lcid, major, minor = typelibInfo
# --> 257     tlb = pythoncom.LoadRegTypeLib(typelibCLSID, major, minor, lcid)
#     258     spec = selecttlb.TypelibSpec(typelibCLSID, lcid, major, minor)
#     259     spec.FromTypelib(tlb, str(typelibCLSID))
#
# com_error: (-2147319779, '라이브러리가 등록되지 않았습니다.', None, None)
